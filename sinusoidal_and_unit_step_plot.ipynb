# %%
import numpy as np
import matplotlib.pyplot as plt

# Continuous function x(t) = sin(t)
t = np.linspace(-5, 5, 1000)  # Generate 1000 points between -5 and 5
x_t = np.sin(t)                # Calculate sin(t)

# Discrete unit step function
n = np.arange(1, 5)            # Discrete values for n = 1, 2, 3, 4
u_n = np.ones_like(n)          # u(n) = 1 for n = 1, 2, 3, 4

# Create the figure and axes
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Plot the continuous function
ax1.plot(t, x_t, label='x(t) = sin(t)', color='blue')
ax1.axhline(0, color='black', linewidth=0.5, linestyle='--')
ax1.axvline(0, color='black', linewidth=0.5, linestyle='--')
ax1.set_title('Continuous Function: x(t) = sin(t)')
ax1.set_xlabel('t')
ax1.set_ylabel('x(t)')
ax1.grid()
ax1.legend()

# Plot the discrete unit step function
ax2.stem(n, u_n, basefmt=" ", linefmt='r-', markerfmt='ro')  # Specify formats
ax2.axhline(0, color='black', linewidth=0.5, linestyle='--')
ax2.set_title('Discrete Unit Step Function: u(n)')
ax2.set_xlabel('n')
ax2.set_ylabel('u(n)')
ax2.set_ylim(-0.5, 1.5)
ax2.grid()

# Show the plots
plt.tight_layout()
plt.show()
