# %%
import numpy as np
import matplotlib.pyplot as plt

# Data provided
etch_rate_actual = np.array([575, 542, 530, 539, 570, 565, 593, 590, 579, 610, 600, 651, 610, 637, 629, 725, 700, 715, 685, 710])
etch_rate_predicted = np.array([551.2, 587.4, 625.4, 707.0, 551.2, 587.4, 625.4, 707.0, 551.2, 587.4, 625.4, 707.0, 551.2, 587.4, 625.4, 707.0, 551.2, 587.4, 625.4, 707.0])

# Calculating residuals
etch_rate_residuals = etch_rate_actual - etch_rate_predicted

# Plot 1: Actual vs Predicted Plot
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.scatter(etch_rate_predicted, etch_rate_actual, color='blue')
plt.plot([etch_rate_predicted.min(), etch_rate_predicted.max()], 
         [etch_rate_predicted.min(), etch_rate_predicted.max()], 
         'k--', lw=2)
plt.title('Actual vs Predicted Etch Rate (R² = 0.93, RMSE = 18.27)')
plt.xlabel('Predicted Etch Rate')
plt.ylabel('Actual Etch Rate')
plt.grid()

# Plot 2: Residuals vs Predicted Plot
plt.subplot(1, 2, 2)
plt.scatter(etch_rate_predicted, etch_rate_residuals, color='green')
plt.axhline(0, color='red', linestyle='--')
plt.title('Residuals vs Predicted Etch Rate')
plt.xlabel('Predicted Etch Rate')
plt.ylabel('Residuals')
plt.grid()

plt.tight_layout()
plt.show()

# Output statistical information
print("Summary of Fit")
print(f"RSquare: 0.92606")
print(f"RSquare Adj: 0.912196")
print(f"Root Mean Square Error: 18.26746")
print(f"Mean of Response: 617.75")
print(f"Observations: 20\n")

print("Analysis of Variance")
print(f"Source\t\tDF\tSum of Squares\tMean Square\tF Ratio")
print(f"Model\t\t3\t66870.550\t22290.2\t66.7971")
print(f"Error\t\t16\t5339.200\t333.7\tProb > F")
print(f"C. Total\t19\t72209.750\t\t<.0001\n")

print("Effect Tests")
print(f"Source\t\tNparm\tDF\tSum of Squares\tF Ratio\tProb > F")
print(f"RF power\t3\t3\t66870.550\t66.7971\t<.0001\n")

print("Least Squares Means Table")
print(f"Level\tLeast Sq Mean\tStd Error\tMean")
print(f"160\t551.20000\t8.1694553\t551.200")
print(f"180\t587.40000\t8.1694553\t587.400")
print(f"200\t625.40000\t8.1694553\t625.400")
print(f"220\t707.00000\t8.1694553\t707.000")
# Out:
# Summary of Fit
# RSquare: 0.92606
# RSquare Adj: 0.912196
# Root Mean Square Error: 18.26746
# Mean of Response: 617.75
# Observations: 20
#
# Analysis of Variance
# Source		DF	Sum of Squares	Mean Square	F Ratio
# Model		3	66870.550	22290.2	66.7971
# Error		16	5339.200	333.7	Prob > F
# C. Total	19	72209.750		<.0001
#
# Effect Tests
# Source		Nparm	DF	Sum of Squares	F Ratio	Prob > F
# RF power	3	3	66870.550	66.7971	<.0001
#
# Least Squares Means Table
# Level	Least Sq Mean	Std Error	Mean
# 160	551.20000	8.1694553	551.200
# 180	587.40000	8.1694553	587.400
# 200	625.40000	8.1694553	625.400
# 220	707.00000	8.1694553	707.000
